# %%
import os
import glob
import pandas as pd
os.chdir(r"/content/drive/My Drive/Hurricane_Isaisa")	   #mention path of the folder which has all the excel files
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
df = pd.read_csv(all_filenames.pop())
for csv_name in all_filenames:
    temp = pd.read_csv(csv_name)
    df = df.append(temp)
df.head()                         	       #give you first 5 rows
#df.shape                                   to get it's shape(x*y)
#df.to_csv("Hanna.csv")                     to download it as a .csv file
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       user_id  ...                                  profile_image_url
# 0   x44099900  ...  http://pbs.twimg.com/profile_images/4481099352...
# 1   x44099900  ...  http://pbs.twimg.com/profile_images/4481099352...
# 2   x44099900  ...  http://pbs.twimg.com/profile_images/4481099352...
# 3  x216759733  ...  http://pbs.twimg.com/profile_images/1050025704...
# 4  x216759733  ...  http://pbs.twimg.com/profile_images/1050025704...
#
# [5 rows x 90 columns]

# %%
df.drop_duplicates()                 #to remove duplicates from the dataframe
# Out:
#            user_id  ...                                  profile_image_url
# 0        x44099900  ...  http://pbs.twimg.com/profile_images/4481099352...
# 1        x44099900  ...  http://pbs.twimg.com/profile_images/4481099352...
# 2        x44099900  ...  http://pbs.twimg.com/profile_images/4481099352...
# 3       x216759733  ...  http://pbs.twimg.com/profile_images/1050025704...
# 4       x216759733  ...  http://pbs.twimg.com/profile_images/1050025704...
# ...            ...  ...                                                ...
# 17908    x71015145  ...  http://pbs.twimg.com/profile_images/5565243556...
# 17909   x104193216  ...  http://pbs.twimg.com/profile_images/1268733853...
# 17910  x2230475744  ...  http://pbs.twimg.com/profile_images/3788000008...
# 17911   x735348997  ...  http://pbs.twimg.com/profile_images/7238085205...
# 17912   x298253644  ...  http://pbs.twimg.com/profile_images/1017199821...
#
# [87482 rows x 90 columns]
