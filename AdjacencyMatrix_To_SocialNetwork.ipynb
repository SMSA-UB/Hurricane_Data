# %%
import pandas as pd
import networkx as nx
input_data = pd.read_csv('network.csv', index_col=0)     #enter the csv file with which you want to create a social network
G = nx.DiGraph(input_data.values)
nx.draw(G, with_labels = True)
